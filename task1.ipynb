# %% [markdown]
# ### STEP 1: Import Libraries & Load Data

# %%
# Install if not already
# !pip install textblob

# Imports
import pandas as pd
import numpy as np
import re
import string

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
# Out:
# Collecting textblob
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\ishik\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\ishik\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ishik\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ishik\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\ishik\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\ishik\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %% [markdown]
# ###  Step 2: Download Required NLTK Data

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Step 3: Load Your Dataset

# %%
df = pd.read_excel("ai_dev_assignment_tickets_complex_1000.xlsx")
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ###  STEP 4: Handle Missing Values

# %%
# Check for missing values
print(df.isnull().sum())

# Option 1: Drop rows with any missing values (if small in number)
df = df.dropna()

# Reset index
df.reset_index(drop=True, inplace=True)

# Confirm removal
print(f"Remaining rows: {df.shape[0]}")
# Out:
# ticket_id        0
# ticket_text      0
# issue_type       0
# urgency_level    0
# product          0
# dtype: int64
# Remaining rows: 826

# %% [markdown]
# ### STEP 5: Text Cleaning Function

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)
    text = re.sub(r"\d+", '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

df['clean_text'] = df['ticket_text'].apply(clean_text)

# %% [markdown]
# ### STEP 6: Feature Engineering

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize vectorizer
tfidf = TfidfVectorizer(max_features=300)  # you can increase if needed

# Fit and transform the text
tfidf_matrix = tfidf.fit_transform(df['clean_text'])

# Convert to DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf.get_feature_names_out())

# %% [markdown]
# ### 2. Ticket Length Feature

# %%
df['ticket_length'] = df['clean_text'].apply(lambda x: len(x.split()))

# %% [markdown]
# ###  3. Sentiment Score (using TextBlob)

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['sentiment_score'] = df['clean_text'].apply(get_sentiment)

# %%
# Combine tfidf with custom features
X = pd.concat([tfidf_df, df[['ticket_length', 'sentiment_score']].reset_index(drop=True)], axis=1)

# Target variables
y_issue = df['issue_type']
y_urgency = df['urgency_level']

# %% [markdown]
# ### Step 6.1: Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# For issue_type
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X, y_issue, test_size=0.2, random_state=42)

# For urgency_level
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y_urgency, test_size=0.2, random_state=42)

# %% [markdown]
# ###  Step 6.2: Train Logistic Regression Models

# %%
from sklearn.linear_model import LogisticRegression

# Issue Type Classifier
model_issue = LogisticRegression(max_iter=1000)
model_issue.fit(X_train_1, y_train_1)

# Urgency Level Classifier
model_urgency = LogisticRegression(max_iter=1000)
model_urgency.fit(X_train_2, y_train_2)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ###  Step 6.3: Evaluate Both Models

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# ISSUE TYPE
print("Issue Type Classification Report:")
y_pred_1 = model_issue.predict(X_test_1)
print(classification_report(y_test_1, y_pred_1))
print("Confusion Matrix:\n", confusion_matrix(y_test_1, y_pred_1))
print("Accuracy:", accuracy_score(y_test_1, y_pred_1))

# URGENCY LEVEL
print("\nUrgency Level Classification Report:")
y_pred_2 = model_urgency.predict(X_test_2)
print(classification_report(y_test_2, y_pred_2))
print("Confusion Matrix:\n", confusion_matrix(y_test_2, y_pred_2))
print("Accuracy:", accuracy_score(y_test_2, y_pred_2))
# Out:
# Issue Type Classification Report:
#                     precision    recall  f1-score   support
#
#     Account Access       1.00      1.00      1.00        23
#    Billing Problem       1.00      1.00      1.00        19
#    General Inquiry       1.00      1.00      1.00        25
# Installation Issue       1.00      1.00      1.00        29
#      Late Delivery       1.00      1.00      1.00        17
#     Product Defect       1.00      1.00      1.00        30
#         Wrong Item       1.00      1.00      1.00        23
#
#           accuracy                           1.00       166
#          macro avg       1.00      1.00      1.00       166
#       weighted avg       1.00      1.00      1.00       166
#
# Confusion Matrix:
#  [[23  0  0  0  0  0  0]
#  [ 0 19  0  0  0  0  0]
#  [ 0  0 25  0  0  0  0]
#  [ 0  0  0 29  0  0  0]
#  [ 0  0  0  0 17  0  0]
#  [ 0  0  0  0  0 30  0]
#  [ 0  0  0  0  0  0 23]]
# Accuracy: 1.0
#
# Urgency Level Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.40      0.35      0.37        66
#          Low       0.30      0.33      0.31        43
#       Medium       0.31      0.33      0.32        57
#
#     accuracy                           0.34       166
#    macro avg       0.34      0.34      0.33       166
# weighted avg       0.34      0.34      0.34       166
#
# Confusion Matrix:
#  [[23 17 26]
#  [12 14 17]
#  [22 16 19]]
# Accuracy: 0.3373493975903614

# %% [markdown]
# ### Step 7.1: Extract Product Name

# %%
# Create a list of known product names
product_list = df['product'].unique().tolist()

def extract_product(text):
    for product in product_list:
        if product.lower() in text.lower():
            return product
    return None

# %% [markdown]
# ### Step 7.2: Extract Complaint Keywords

# %%
complaint_keywords = [
    'broken', 'defective', 'late', 'missing', 'damaged', 'error', 'issue',
    'problem', 'not working', 'delay', 'wrong', 'cancelled', 'failed'
]

def extract_complaints(text):
    found = [word for word in complaint_keywords if word in text.lower()]
    return found if found else None

# %% [markdown]
# ###  Step 7.3: Extract Dates

# %%
import re

def extract_dates(text):
    date_pattern = r'\b(?:\d{1,2}[/-]\d{1,2}[/-]\d{2,4}|\d{1,2}(?:st|nd|rd|th)?\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)\b'
    dates = re.findall(date_pattern, text)
    return dates if dates else None

# %% [markdown]
# ### Step 7.4: Combine into One Function

# %%
def extract_entities(text):
    return {
        'product': extract_product(text),
        'dates': extract_dates(text),
        'complaints': extract_complaints(text)
    }

# %%
df['entities'] = df['ticket_text'].apply(extract_entities)
df[['ticket_text', 'entities']].head()
# Extracted product as separate column
df['extracted_product'] = df['ticket_text'].apply(lambda x: extract_product(x))

# Compare to actual (ground truth) product column
df['product_match'] = df['extracted_product'] == df['product']

# Evaluate match rate
match_rate = df['product_match'].mean()
print(f"✅ Product Extraction Accuracy: {match_rate:.2%}")
# Out:
# ✅ Product Extraction Accuracy: 56.30%

# %% [markdown]
# ### Step 8: Final Integration Function

# %%
def preprocess_input(text):
    text = clean_text(text)
    ticket_length = len(text.split())
    sentiment = get_sentiment(text)
    
    # TF-IDF vector (same columns as training)
    tfidf_vector = tfidf.transform([text]).toarray()
    full_features = np.append(tfidf_vector, [[ticket_length, sentiment]], axis=1)
    
    return full_features

# %%
def analyze_ticket(ticket_text):
    features = preprocess_input(ticket_text)

    # Predictions
    predicted_issue = model_issue.predict(features)[0]
    predicted_urgency = model_urgency.predict(features)[0]
    extracted_entities = extract_entities(ticket_text)

    return {
        "predicted_issue_type": predicted_issue,
        "predicted_urgency_level": predicted_urgency,
        "extracted_entities": extracted_entities
    }

# %%
test_text = "Order #19283 for SmartWatch V2 arrived broken and 5 days late. Please fix this issue ASAP!"
result = analyze_ticket(test_text)

import json
print(json.dumps(result, indent=2))
# Out:
# {
#   "predicted_issue_type": "Late Delivery",
#   "predicted_urgency_level": "Medium",
#   "extracted_entities": {
#     "product": "SmartWatch V2",
#     "dates": null,
#     "complaints": [
#       "broken",
#       "late",
#       "issue"
#     ]
#   }
# }
# C:\Users\ishik\anaconda3\envs\ai-assignment\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\ishik\anaconda3\envs\ai-assignment\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (5.35.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.116.0)
# Requirement already satisfied: ffmpy in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.4 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (1.10.4)
# Requirement already satisfied: groovy~=0.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.33.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (1.24.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (2.3.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.12.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (4.14.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio-client==1.10.4->gradio) (2025.5.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from gradio-client==1.10.4->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: colorama in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: certifi in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from httpx>=0.24.1->gradio) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ishik\anaconda3\envs\ai-assignment\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import json

def gradio_interface(text):
    result = analyze_ticket(text)
    entities = result["extracted_entities"]

    return (
        result["predicted_issue_type"],
        result["predicted_urgency_level"],
        entities.get("product", "Not found"),
        json.dumps(entities, indent=2)
    )

demo = gr.Interface(
    fn=gradio_interface,
    inputs=gr.Textbox(lines=4, label="Enter Ticket Text"),
    outputs=[
        gr.Label(label="Predicted Issue Type"),
        gr.Label(label="Predicted Urgency Level"),
        gr.Label(label="Extracted Product Name"),
        gr.Textbox(label="Extracted Entities (Full JSON)")
    ],
    title=" AI-Powered Support Ticket Analyzer",
    description="Paste a raw customer ticket below to classify and extract key insights including product name."
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
